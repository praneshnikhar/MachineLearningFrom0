# %%
import os
from huggingface_hub import InferenceClient

client = InferenceClient(
    provider="hf-inference",
    api_key=os.environ["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"],
)

result = client.text_classification(
    "I like you. I love you",
    model="Hello-SimpleAI/chatgpt-detector-roberta",
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 6
#       1 import os
#       2 from huggingface_hub import InferenceClient
#       4 client = InferenceClient(
#       5     provider="hf-inference",
# ----> 6     api_key=os.environ["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"],
#       7 )
#       9 result = client.text_classification(
#      10     "I like you. I love you",
#      11     model="Hello-SimpleAI/chatgpt-detector-roberta",
#      12 )
#
# File <frozen os>:716, in __getitem__(self, key)
#
# KeyError: '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'
