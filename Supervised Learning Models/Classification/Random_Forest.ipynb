# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = load_iris()

# %%
X = pd.DataFrame(data=iris.data, columns=iris.feature_names)
y = pd.Series(iris.target)

# %%
print("Features (X):")
print(X.head())
# Out:
# Features (X):
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
print("\nTarget (y):")
print(y.head())
# Out:
# Target (y):
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
rf_classifier.fit(X_train, y_train)
y_pred = rf_classifier.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"\nAccuracy: {accuracy:.2f}")
# Out:
# Accuracy: 1.00

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Reds',
            xticklabels=iris.target_names, yticklabels=iris.target_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix for Random Forest Classifier')
plt.show()

# %%
class_report = classification_report(y_test, y_pred, target_names=iris.target_names)
print("\nClassification Report:")
print(class_report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       1.00      1.00      1.00        13
#    virginica       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
accuracy_score = rf_classifier.score(X_test, y_test)
print(f"\nModel Accuracy using score method: {accuracy_score:.2f}")
# Out:
# Model Accuracy using score method: 1.00

# %%
from fastai.imports import *
np.set_printoptions(linewidth=130)

# %%
pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (1.8.2)
# Requirement already satisfied: black>=24.10.0 in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from kaggle) (25.12.0)
# Requirement already satisfied: bleach in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from kaggle) (6.3.0)
# Requirement already satisfied: kagglesdk in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from kaggle) (0.1.13)
# Requirement already satisfied: mypy>=1.15.0 in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from kaggle) (1.19.0)
# Requirement already satisfied: protobuf in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from kaggle) (6.33.2)
# Requirement already satisfied: python-dateutil in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from kaggle) (2.32.5)
# Requirement already satisfied: setuptools>=21.0.0 in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from kaggle) (80.9.0)
# Requirement already satisfied: six>=1.10 in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from kaggle) (1.17.0)
# Requirement already satisfied: tqdm in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from kaggle) (4.67.1)
# Requirement already satisfied: types-requests in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from kaggle) (2.32.4.20250913)
# Requirement already satisfied: types-tqdm in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from kaggle) (4.67.0.20250809)
# Requirement already satisfied: urllib3>=1.15.1 in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from kaggle) (2.6.2)
# Requirement already satisfied: click>=8.0.0 in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from black>=24.10.0->kaggle) (8.3.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from black>=24.10.0->kaggle) (1.1.0)
# Requirement already satisfied: packaging>=22.0 in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from black>=24.10.0->kaggle) (25.0)
# Requirement already satisfied: pathspec>=0.9.0 in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from black>=24.10.0->kaggle) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from black>=24.10.0->kaggle) (4.5.1)
# Requirement already satisfied: pytokens>=0.3.0 in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from black>=24.10.0->kaggle) (0.3.0)
# Requirement already satisfied: typing_extensions>=4.6.0 in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from mypy>=1.15.0->kaggle) (4.15.0)
# Requirement already satisfied: librt>=0.6.2 in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from mypy>=1.15.0->kaggle) (0.7.3)
# Requirement already satisfied: webencodings in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from requests->kaggle) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from requests->kaggle) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from requests->kaggle) (2025.11.12)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
iskaggle = os.environ.get('KAGGLE_KERNEL_RUN_TYPE', '')

if iskaggle: path = Path('/Users/pranesh/coding2/MachineLearningFrom0/NN/Titanic-Dataset.csv')
else:
    
    path = Path('/Users/pranesh/coding2/MachineLearningFrom0/NN/Titanic-Dataset.csv')


df = pd.read_csv(path/'/Users/pranesh/coding2/MachineLearningFrom0/NN/Titanic-Dataset.csv')
tst_df = pd.read_csv(path/'/Users/pranesh/coding2/MachineLearningFrom0/NN/Titanic-Dataset.csv')
modes = df.mode().iloc[0]

# %%
def proc_data(df):
    df['Fare'] = df.Fare.fillna(0)
    df.fillna(modes, inplace=True)
    df['LogFare'] = np.log1p(df['Fare'])
    df['Embarked'] = pd.Categorical(df.Embarked)
    df['Sex'] = pd.Categorical(df.Sex)

proc_data(df)
proc_data(tst_df)

# %%
cats=["Sex","Embarked"]
conts=['Age', 'SibSp', 'Parch', 'LogFare',"Pclass"]
dep="Survived"

# %%
df.Sex.head()
# Out:
# 0      male
# 1    female
# 2    female
# 3    female
# 4      male
# Name: Sex, dtype: category
# Categories (2, object): ['female', 'male']

# %%
df.Sex.cat.codes.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    1
# dtype: int8

# %%
import seaborn as sns

fig,axs = plt.subplots(1,2, figsize=(11,5))
sns.barplot(data=df, y=dep, x="Sex", ax=axs[0]).set(title="Survival rate")
sns.countplot(data=df, x="Sex", ax=axs[1]).set(title="Histogram");

# %%
from numpy import random
from sklearn.model_selection import train_test_split

random.seed(42)
trn_df,val_df = train_test_split(df, test_size=0.25)
trn_df[cats] = trn_df[cats].apply(lambda x: x.cat.codes)
val_df[cats] = val_df[cats].apply(lambda x: x.cat.codes)

# %%
def xs_y(df):
    xs = df[cats+conts].copy()
    return xs,df[dep] if dep in df else None

trn_xs,trn_y = xs_y(trn_df)
val_xs,val_y = xs_y(val_df)

# %%
preds = val_xs.Sex==0

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(val_y, preds)
# Out:
# 0.21524663677130046

# %%
df_fare = trn_df[trn_df.LogFare>0]
fig,axs = plt.subplots(1,2, figsize=(11,5))
sns.boxenplot(data=df_fare, x=dep, y="LogFare", ax=axs[0])
sns.kdeplot(data=df_fare, x="LogFare", ax=axs[1]);

# %%
preds = val_xs.LogFare>2.7

# %%
mean_absolute_error(val_y, preds)
# Out:
# 0.336322869955157

# %%
def _side_score(side, y):
    tot = side.sum()
    if tot<=1: return 0
    return y[side].std()*tot

# %%
def score(col, y, split):
    lhs = col<=split
    return (_side_score(lhs,y) + _side_score(~lhs,y))/len(y)

# %%
score(trn_xs["Sex"], trn_y, 0.5)
# Out:
# np.float64(0.40787530982063946)

# %%
score(trn_xs["LogFare"], trn_y, 2.7)
# Out:
# np.float64(0.47180873952099694)

# %%
pip install ipywidgets
# Out:
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: comm>=0.1.3 in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from ipywidgets) (9.8.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from ipywidgets) (5.14.3)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets)
#   Downloading widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets)
#   Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: decorator>=4.3.2 in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/pranesh/coding2/MachineLearningFrom0/.venv/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (0.2.3)
# Downloading ipywidgets-8.1.8-py3-none-any.whl (139 kB)
# Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl (914 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 6.7 MB/s  0:00:00
# Downloading widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 4.7 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: widgetsnbextension, jupyterlab_widgets, ipywidgets
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [ipywidgets]
# Successfully installed ipywidgets-8.1.8 jupyterlab_widgets-3.0.16 widgetsnbextension-4.0.15
# Note: you may need to restart the kernel to use updated packages.

# %%
def iscore(nm, split):
    col = trn_xs[nm]
    return score(col, trn_y, split)

from ipywidgets import interact
interact(nm=conts, split=15.5)(iscore)

# %%
interact(nm=cats, split=2)(iscore)

# %%
nm = "Age"
col = trn_xs[nm]
unq = col.unique()
unq.sort()
unq

# %%
scores = np.array([score(col, trn_y, o) for o in unq if not np.isnan(o)])
unq[scores.argmin()]

# %%
def min_col(df, nm):
    col,y = df[nm],df[dep]
    unq = col.dropna().unique()
    scores = np.array([score(col, y, o) for o in unq if not np.isnan(o)])
    idx = scores.argmin()
    return unq[idx],scores[idx]

min_col(trn_df, "Age")

# %%
cols = cats+conts
{o:min_col(trn_df, o) for o in cols}

# %%
cols.remove("Sex")
ismale = trn_df.Sex==1
males,females = trn_df[ismale],trn_df[~ismale]

# %%
{o:min_col(males, o) for o in cols}

# %%
{o:min_col(females, o) for o in cols}

# %%
from sklearn.tree import DecisionTreeClassifier, export_graphviz

m = DecisionTreeClassifier(max_leaf_nodes=4).fit(trn_xs, trn_y);

# %%
pip install graphviz

# %%
import graphviz

def draw_tree(t, df, size=10, ratio=0.6, precision=2, **kwargs):
    s=export_graphviz(t, out_file=None, feature_names=df.columns, filled=True, rounded=True,
                      special_characters=True, rotate=False, precision=precision, **kwargs)
    return graphviz.Source(re.sub('Tree {', f'Tree {{ size={size}; ratio={ratio}', s))

# %%
draw_tree(m, trn_xs, size=10)

# %%
def gini(cond):
    act = df.loc[cond, dep]
    return 1 - act.mean()**2 - (1-act).mean()**2

# %%
gini(df.Sex=='female'), gini(df.Sex=='male')

# %%
mean_absolute_error(val_y, m.predict(val_xs))

# %%
m = DecisionTreeClassifier(min_samples_leaf=50)
m.fit(trn_xs, trn_y)
draw_tree(m, trn_xs, size=12)

# %%
mean_absolute_error(val_y, m.predict(val_xs))

# %%
tst_df[cats] = tst_df[cats].apply(lambda x: x.cat.codes)
tst_xs,_ = xs_y(tst_df)

def subm(preds, suff):
    tst_df['Survived'] = preds
    sub_df = tst_df[['PassengerId','Survived']]
    sub_df.to_csv(f'sub-{suff}.csv', index=False)

subm(m.predict(tst_xs), 'tree')

# %%
df.Embarked.head()

# %%
df.Embarked.cat.codes.head()

# %%
def get_tree(prop=0.75):
    n = len(trn_y)
    idxs = random.choice(n, int(n*prop))
    return DecisionTreeClassifier(min_samples_leaf=5).fit(trn_xs.iloc[idxs], trn_y.iloc[idxs])

# %%
trees = [get_tree() for t in range(100)]

# %%
all_probs = [t.predict(val_xs) for t in trees]
avg_probs = np.stack(all_probs).mean(0)

mean_absolute_error(val_y, avg_probs)

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(100, min_samples_leaf=5)
rf.fit(trn_xs, trn_y);
mean_absolute_error(val_y, rf.predict(val_xs))

# %%
subm(rf.predict(tst_xs), 'rf')

# %%
pd.DataFrame(dict(cols=trn_xs.columns, imp=m.feature_importances_)).plot('cols', 'imp', 'barh');
